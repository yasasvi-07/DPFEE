# %%
import numpy as np

# %%
import pandas as pd

# %%
d1={'c1':[1,2,3],'c2':[7,2,9],}
d2={'c2':[6,2,15],'c4':[10,11,12]}

# %%
df1=pd.DataFrame(d1)

# %%
df1
# Out:
#    c1  c2
# 0   1   7
# 1   2   2
# 2   3   9

# %%
df2=pd.DataFrame(d2)

# %%
df2
# Out:
#    c2  c4
# 0   6  10
# 1   2  11
# 2  15  12

# %%
pd.concat([df1,df2])
# Out:
#     c1  c2    c4
# 0  1.0   7   NaN
# 1  2.0   2   NaN
# 2  3.0   9   NaN
# 0  NaN   6  10.0
# 1  NaN   2  11.0
# 2  NaN  15  12.0

# %%
pd.merge(df1,df2,how="inner", on='c2')
# Out:
#    c1  c2  c4
# 0   2   2  11

# %%
a1={"student":['sam','ram','jack',"jerry"],"marks":[10,20,3,40]}
a2={"student":['rahul','ram','roy'],"usn":[40,50,60]}

# %%
a4=pd.DataFrame(a1)

# %%
a4
# Out:
#   student  marks
# 0     sam     10
# 1     ram     20
# 2    jack      3
# 3   jerry     40

# %%
a5=pd.DataFrame(a2)

# %%
a5
# Out:
#   student  usn
# 0   rahul   40
# 1     ram   50
# 2     roy   60

# %%
pd.merge(a4,a5,how="inner", on='student')
# Out:
#   student  marks  usn
# 0     ram     20   50

# %%
pd.merge(a4,a5,how="left", on='student')
# Out:
#   student  marks   usn
# 0     sam     10   NaN
# 1     ram     20  50.0
# 2    jack      3   NaN
# 3   jerry     40   NaN

# %%
import pandas as pd

# %%
data=pd.read_csv("billionaire.csv")

# %%
data
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                          name   last_name  age gender  time  \
# 0         675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 1         676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 2         677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 3         678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 4         679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
#
#             permanent_country       company main_industry  \
# 0  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 1  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 2  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 3  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 4  United Arab Emirates-Dubai  Mashreq Bank   Diversified
#
#   wealth_source_details             industry state headquarters countries  \
# 0           diversified  Diversified;Banking   NaN          NaN       are
# ...

# %%
data.isnull()
# Out:
#         Unnamed: 0   name  last_name    age  gender   time  permanent_country  \
# 0            False  False      False  False   False  False              False
# 1            False  False      False  False   False  False              False
# 2            False  False      False  False   False  False              False
# 3            False  False      False  False   False  False              False
# 4            False  False      False  False   False  False              False
# ...            ...    ...        ...    ...     ...    ...                ...
# 352364       False  False      False  False   False  False              False
# 352365       False  False      False  False   False  False              False
# 352366       False  False      False  False   False  False              False
# 352367       False  False      False  False   False  False              False
# 352368       False  False      False  False   False  False              False
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# name                          0
# last_name                 10850
# age                           0
# gender                    11892
# time                          0
# permanent_country         47691
# company                   25500
# main_industry                 0
# wealth_source_details     10922
# industry                     49
# state                    193179
# headquarters             218714
# countries                     0
# annual_income                 0
# daily_income                  0
# birth_year                    0
# name_cleaned                  0
# dtype: int64

# %%
data["last_name"].nunique()
# Out:
# 2407

# %%
data.tail()
# Out:
#         Unnamed: 0                name   last_name  age gender  time  \
# 352364      358313  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
# 352365      358314  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
# 352366      358315  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
# 352367      358316  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
# 352368      358317  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
#
#        permanent_country         company          main_industry  \
# 352364     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
# 352365     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
# 352366     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
# 352367     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
# 352368     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
#
#               wealth_source_details  \
# 352364  TV broadcasting; TV station
# 352365  TV broadcasting; TV station
# 352366  TV broadcasting; TV station
# ...

# %%
data.fillna(100)
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
d1=data.fillna(100)

# %%
d1.isnull().sum()
# Out:
# Unnamed: 0               0
# name                     0
# last_name                0
# age                      0
# gender                   0
# time                     0
# permanent_country        0
# company                  0
# main_industry            0
# wealth_source_details    0
# industry                 0
# state                    0
# headquarters             0
# countries                0
# annual_income            0
# daily_income             0
# birth_year               0
# name_cleaned             0
# dtype: int64

# %%
a1={"us":[101,102,103],"name":["tom","jerry","sai"]}
a2={"usn":[101,104,105],"marks":[22,33,44]}

# %%
d=pd.DataFrame(a1)

# %%
d
# Out:
#     us   name
# 0  101    tom
# 1  102  jerry
# 2  103    sai

# %%
d1=pd.DataFrame(a2)

# %%
d1
# Out:
#    usn  marks
# 0  101     22
# 1  104     33
# 2  105     44

# %%
pd.merge(d,d1,how="inner",on="usn")
# Out:
#    usn name  marks
# 0  101  tom     22

# %%
pd.merge(d,d1,how="left",on="usn")
# Out:
#    usn   name  marks
# 0  101    tom   22.0
# 1  102  jerry    NaN
# 2  103    sai    NaN

# %%
pd.merge(d,d1,how="right",on="usn")
# Out:
#    usn name  marks
# 0  101  tom     22
# 1  104  NaN     33
# 2  105  NaN     44

# %%
d.join(d1)
# Out:
#     us   name  usn  marks
# 0  101    tom  101     22
# 1  102  jerry  104     33
# 2  103    sai  105     44

# %%
import pandas as pd

# %%
data=pd.read_csv("billionaire.csv")

# %%
data
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
g=pd.DataFrame(data)

# %%
g
# Out:
#         Unnamed: 0                          name   last_name  age gender  \
# 0              675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 1              676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 2              677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 3              678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# 4              679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M
# ...            ...                           ...         ...  ...    ...
# 352364      358313            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352365      358314            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352366      358315            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352367      358316            Zygmunt Solorz-Zak  Solorz-Zak   65      M
# 352368      358317            Zygmunt Solorz-Zak  Solorz-Zak   65      M
#
#         time           permanent_country         company  \
# ...

# %%
d1=pd.read_excel("stress1.xlsx")

# %%
d1
# Out:
#     name  age  exam stress
# 0    ram   12            1
# 1  jithu   18            0
# 2    sam   19            1

# %%
g1=pd.DataFrame(d1)

# %%
g1
# Out:
#     name  age  exam stress
# 0    ram   12            1
# 1  jithu   18            0
# 2    sam   19            1
